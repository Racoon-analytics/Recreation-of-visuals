# %%
import matplotlib.pyplot as plt
import pandas as pd



df = pd.DataFrame({"Роки":["2010", "2011", "2012", "2013", "2014", "2015", "2016", "2017", "2018"],
                   "Україна":[29, 21, 21, 21, 12, 12, 12, 12, 12],
                   "Польща":[20, 20, 20, 18, 18, 16, 16, 12, 12],
                   "Румунія":[19, 22, 23, 23, 23, 23, 24, 24, 24],
                   "США - Нью Йорк":[14, 15, 15, 15, 15, 15, 15, 15, 15],
                   "Німеччина":[9, 9, 9, 9, 9, 9, 9, 9, 9]})

fig, ax = plt.subplots(figsize=(12, 3.5))

lw = 12
s=120

ax.plot(df["Роки"], df["Україна"], label="Україна", color="#c4161c", linewidth=lw, alpha=0.9)
ax.scatter(df["Роки"], df["Україна"], color="#c4161c", marker='s', s=s)

ax.plot(df["Роки"], df["Польща"], label="Польща", color="#e65100", linewidth=lw, alpha=0.8)
ax.scatter(df["Роки"], df["Польща"], color="#e65100", marker='s', s=s)

ax.plot(df["Роки"], df["Румунія"], label="Румунія", color="#ef6c00", linewidth=lw, alpha=0.7)
ax.scatter(df["Роки"], df["Румунія"], color="#ef6c00", marker='s', s=s)

ax.plot(df["Роки"], df["США - Нью Йорк"], label="США - Нью Йорк", color="#ff9800", linewidth=lw, alpha=0.7)
ax.scatter(df["Роки"], df["США - Нью Йорк"], color="#ff9800", marker='s', s=s)

ax.plot(df["Роки"], df["Німеччина"], label="Німеччина", color="#ef9a9a", linewidth=lw, alpha=0.5)
ax.scatter(df["Роки"], df["Німеччина"], color="#ef9a9a", marker='s', s=s)


ax.set_title("Отримання дозволів на будівництво\nКількість процедур на рік", fontsize=14, loc='left')
fig.text(0.15, -0.1, "Дані: doingbusiness.org/en/data...", color='gray', fontsize=12)
ax.set_yticks([29, 20, 19, 14, 9])
ax.set_yticklabels(["Україна 29", "Польща 20", "Румунія 19", "США - Нью Йорк 14", "Німеччина 9"])

ax2 = ax.twinx()
ax2.set_ylim(ax.get_ylim())
ax2.set_yticks([12, 24, 15, 9])
ax2.set_yticklabels(["12 Україна, Польща","24 Румунія", "15 США - Нью Йорк", "9 Німеччина"])

ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)
ax.spines['bottom'].set_visible(False)
ax.spines['left'].set_visible(False)
ax2.spines['top'].set_visible(False)
ax2.spines['right'].set_visible(False)
ax2.spines['bottom'].set_visible(False)
ax2.spines['left'].set_visible(False)



ax.set_xticks(df["Роки"])
ax.xaxis.set_tick_params(length=0)
ax.yaxis.set_tick_params(length=0)
ax2.yaxis.set_tick_params(length=0)
